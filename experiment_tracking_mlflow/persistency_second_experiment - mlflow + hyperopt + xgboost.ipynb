# %% [markdown]
# #### Checking Python version

# %%
# !python -V
# Out:
# Python 3.8.8

# %% [markdown]
# This is the same code present in `persistency_base_model - modified data2.ipynb`. I have just copied the notebook and renamed it

# %% [markdown]
# #### Importing libraries

# %%
import os
import warnings
warnings.simplefilter("ignore", UserWarning)

import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)

from datetime import datetime as dt
import pickle

import matplotlib.pyplot as plt
from matplotlib.figure import Figure
# %matplotlib inline
import seaborn as sns

from feature_engine import encoding as ce
from feature_engine import imputation as mdi
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

from sklearn.model_selection import train_test_split
# from sklearn.linear_model import LogisticRegression
# from sklearn.ensemble import GradientBoostingClassifier
import xgboost as xgb

from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

from sklearn.metrics import roc_auc_score, classification_report, confusion_matrix, accuracy_score, recall_score, precision_score, f1_score
import sklearn.metrics as metrics

# %% [markdown]
# #### Importing mlflow and setting tracking uri

# %%
import mlflow

mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("persistency-prediction-experiment")
# Out:
# <Experiment: artifact_location='./mlruns/1', creation_time=1673260171550, experiment_id='1', last_update_time=1673260171550, lifecycle_stage='active', name='persistency-prediction-experiment', tags={}>

# %% [markdown]
# #### Importing data

# %%
INPUT_FILEPATH = 'data'
INPUT_FILENAME = 'master_data_final.csv'

INDEX = 'policy_number'
DATE_COLS = ['proposal_received_date', 'policy_issue_date', 'agent_dob', 'agent_doj']
NA_VALUES = ['', 'NA', 'N/A', 'NULL', 'null', '?', '*', '#N/A', '#VALUE!']
DTYPE_DICT = {'zipcode': 'str', 'agent_code': 'str'} ## THese columns should be string

# %%
def load_data(INPUT_FILEPATH, INPUT_FILENAME):
    input_df = pd.read_csv(os.path.join(INPUT_FILEPATH, INPUT_FILENAME),
                      index_col = INDEX,
                      na_values = NA_VALUES,
                      parse_dates = DATE_COLS,
                      dayfirst = True,
                      dtype = DTYPE_DICT)
                    
    return input_df

# %%
input_df = load_data(INPUT_FILEPATH, INPUT_FILENAME)

# %%
input_df.head(10)
# Out:
#               proposal_received_date policy_issue_date  owner_age  \
# policy_number
# 1                         2020-09-08        2020-09-08         22
# 2                         2020-08-24        2020-08-26         33
# 3                         2020-08-24        2020-08-24         29
# 4                         2020-08-24        2020-08-24         57
# 5                         2020-08-24        2020-08-25         32
# 6                         2020-08-24        2020-08-29         27
# 7                         2020-08-24        2020-08-24         39
# 8                         2020-08-24        2020-09-30         39
# 9                         2020-08-24        2020-08-26         28
# 10                        2020-09-29        2020-09-30         28
#
#               owner_gender marital_status  num_nominee smoker medical  \
# policy_number
# 1                   Female         Single            1     No      No
# 2                   Female         Single            1     No      No
# 3                   Female        Married            1     No      No
# 4                     Male       Divorced            1     No     Yes
# 5                   Female       Divorced            1     No      No
# 6                     Male         Single            1    Yes     Yes
# 7                     Male        Married            1     No      No
# 8                   Female        Widowed            1    Yes     Yes
# 9                     Male        Married            1     No      No
# 10                    Male         Single            1     No      No
#
#                     education     occupation  experience  income zipcode  \
# policy_number
# 1                    Graduate          Sales           1   50000   19111
# 2                 High School      Housewife           0       0    7764
# 3              Lt High School  Other Service          13  100000   26335
# 4                    Graduate       Military          36  242286   98241
# 5               Post Graduate        Teacher           8   20434   78160
# 6                    Graduate     Accountant           6   65000   15938
# 7                 High School   Govt Service          21  116539   28707
# 8                    Graduate     Shop Owner          18   56924   60129
# 9                    Graduate     IT Service           7   64762   33759
# 10                   Graduate     Shop Owner           7   50000   52211
#
#                             county state  negative_zipcode  family_member  \
# policy_number
# 1              Philadelphia County    PA                 0              1
# 2                  Monmouth County    NJ                 0              1
# 3                   Braxton County    WV                 0              2
# 4                    Skagit County    WA                 0              3
# 5                    Wilson County    TX                 0              1
# 6                   Cambria County    PA                 0              1
# 7                   Jackson County    NC                 0              3
# 8                    DeKalb County    IL                 0              1
# 9                  Pinellas County    FL                 0              3
# 10                Poweshiek County    IA                 0              1
#
#                existing_num_policy  has_critical_health_history  policy_term  \
# policy_number
# 1                                0                            0           25
# 2                                0                            0           20
# 3                                1                            0           10
# 4                                0                            0           15
# 5                                1                            0           20
# 6                                0                            0           20
# 7                                0                            1           10
# 8                                0                            1           15
# 9                                0                            0           25
# 10                               0                            0           10
#
#               payment_freq  annual_premium  sum_insured agent_code  agent_dob  \
# policy_number
# 1                 Annually             377       580019   60503862 1997-07-03
# 2                 Quaterly             671       829002   60422713 1980-03-28
# 3                 Annually             210       659027   60450939 1978-06-25
# 4                 Annually            1863       612890   60394377 1993-05-05
# 5                 Annually             730       879549   60491531 1967-12-05
# 6                 Annually             941       862056   60408239 1986-06-05
# 7                 Annually             331       529537   60476244 1984-11-03
# 8                  Monthly             566       501114   60237645        NaT
# 9                 Annually             477       465743   60221480 1964-10-26
# 10                Quaterly             163       482589   60410983 1983-03-01
#
#                agent_doj agent_status agent_education  agent_age  \
# policy_number
# 1             2020-08-31       Active        Graduate         23
# 2             2018-05-17       Active     High School         40
# 3             2019-02-25     Inactive    Some College         42
# 4             2017-07-10       Active        Graduate         27
# 5             2020-03-20       Active        Graduate         53
# 6             2017-11-30       Active        Graduate         34
# 7             2019-10-22       Active  Lt High School         36
# 8             2012-08-23       Active     High School         36
# 9             2011-10-13       Active  Lt High School         56
# 10            2017-12-27       Active     High School         38
#
#                agent_tenure_days  agent_persistency  last_6_month_submissions  \
# policy_number
# 1                              8               0.76                        35
# 2                            830               0.87                        54
# 3                            546               0.93                         0
# 4                           1141               0.78                        29
# 5                            157               0.89                        44
# 6                            998               0.75                        26
# 7                            307               0.81                        45
# 8                           2923               0.98                        60
# 9                           3238               0.70                        40
# 10                          1007               0.72                        43
#
#                average_premium  is_reinstated  prev_persistency  \
# policy_number
# 1                          377              1              0.67
# 2                          671              0              0.00
# 3                          579              0              0.00
# 4                         1333              1              0.72
# 5                          652              0              0.00
# 6                         1890              0              0.00
# 7                          926              0              0.00
# 8                         1119              0              0.00
# 9                          842              0              0.00
# 10                         637              0              0.00
#
#                num_complaints  target_completion_perc  \
# policy_number
# 1                           1                    0.98
# 2                           4                    0.90
# 3                           8                    0.93
# 4                           8                    0.95
# 5                           8                    0.89
# 6                           8                    0.83
# 7                          13                    0.92
# 8                           8                    0.95
# 9                          27                    0.88
# 10                          7                    0.97
#
#                has_contacted_in_last_6_months  credit_score  lapse
# policy_number
# 1                                           1           762      0
# 2                                           1           794      0
# 3                                           1           800      1
# 4                                           1           850      0
# 5                                           0           745      1
# 6                                           0           720      0
# 7                                           0           686      0
# 8                                           0           838      0
# 9                                           1           773      1
# 10                                          1           796      0

# %% [markdown]
# #### Checking data info

# %%
input_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44948 entries, 1 to 44948
# Data columns (total 40 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   proposal_received_date          44948 non-null  datetime64[ns]
#  1   policy_issue_date               44948 non-null  datetime64[ns]
#  2   owner_age                       44948 non-null  int64
#  3   owner_gender                    44948 non-null  object
#  4   marital_status                  44948 non-null  object
#  5   num_nominee                     44948 non-null  int64
#  6   smoker                          44948 non-null  object
#  7   medical                         44948 non-null  object
#  8   education                       44948 non-null  object
#  9   occupation                      44948 non-null  object
#  10  experience                      44948 non-null  int64
#  11  income                          44948 non-null  int64
#  12  zipcode                         44948 non-null  object
#  13  county                          44948 non-null  object
#  14  state                           44948 non-null  object
#  15  negative_zipcode                44948 non-null  int64
#  16  family_member                   44948 non-null  int64
#  17  existing_num_policy             44948 non-null  int64
#  18  has_critical_health_history     44948 non-null  int64
#  19  policy_term                     44948 non-null  int64
#  20  payment_freq                    44948 non-null  object
#  21  annual_premium                  44948 non-null  int64
#  22  sum_insured                     44948 non-null  int64
#  23  agent_code                      44948 non-null  object
#  24  agent_dob                       35994 non-null  datetime64[ns]
#  25  agent_doj                       44948 non-null  datetime64[ns]
#  26  agent_status                    44948 non-null  object
#  27  agent_education                 44948 non-null  object
#  28  agent_age                       44948 non-null  int64
#  29  agent_tenure_days               44948 non-null  int64
#  30  agent_persistency               44831 non-null  float64
#  31  last_6_month_submissions        44948 non-null  int64
#  32  average_premium                 44948 non-null  int64
#  33  is_reinstated                   44948 non-null  int64
#  34  prev_persistency                44948 non-null  float64
#  35  num_complaints                  44948 non-null  int64
#  36  target_completion_perc          44948 non-null  float64
#  37  has_contacted_in_last_6_months  44948 non-null  int64
#  38  credit_score                    44948 non-null  int64
#  39  lapse                           44948 non-null  int64
# dtypes: datetime64[ns](4), float64(3), int64(20), object(13)
# memory usage: 14.1+ MB

# %%
input_df.columns
# Out:
# Index(['proposal_received_date', 'policy_issue_date', 'owner_age',
#        'owner_gender', 'marital_status', 'num_nominee', 'smoker', 'medical',
#        'education', 'occupation', 'experience', 'income', 'zipcode', 'county',
#        'state', 'negative_zipcode', 'family_member', 'existing_num_policy',
#        'has_critical_health_history', 'policy_term', 'payment_freq',
#        'annual_premium', 'sum_insured', 'agent_code', 'agent_dob', 'agent_doj',
#        'agent_status', 'agent_education', 'agent_age', 'agent_tenure_days',
#        'agent_persistency', 'last_6_month_submissions', 'average_premium',
#        'is_reinstated', 'prev_persistency', 'num_complaints',
#        'target_completion_perc', 'has_contacted_in_last_6_months',
#        'credit_score', 'lapse'],
#       dtype='object')

# %% [markdown]
# #### Target variable distribution

# %%
input_df['lapse'].value_counts()/len(input_df)*100
# Out:
# 0    58.338525
# 1    41.661475
# Name: lapse, dtype: float64

# %% [markdown]
# #### Creating feature: time_to_issue

# %%
def create_time_to_issue(df) -> pd.DataFrame:
    df['time_to_issue'] = (df['policy_issue_date'] - df['proposal_received_date']).dt.days

    return df

# %%
input_df = create_time_to_issue(input_df)
input_df['time_to_issue'].describe()
# Out:
# count    44948.000000
# mean         5.640451
# std         11.153843
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          7.000000
# max        494.000000
# Name: time_to_issue, dtype: float64

# %% [markdown]
# #### Creating feature: prem_to_income_ratio

# %%
def create_prem_to_income_ratio(df) -> pd.DataFrame:
    df['prem_to_income_ratio'] = np.where(df['income'] == 0, 0, (df['annual_premium']/df['income']))

    return df

# %%
input_df = create_prem_to_income_ratio(input_df)
input_df['prem_to_income_ratio'].describe()
# Out:
# count    44948.000000
# mean         0.016824
# std          0.025457
# min          0.000000
# 25%          0.004170
# 50%          0.008553
# 75%          0.017717
# max          0.200000
# Name: prem_to_income_ratio, dtype: float64

# %% [markdown]
# ## --------------------------------------------------------------------------------------------------------------------------------
#
# The objective of this exercise is to create a demoable solution (maybe not the best possible one, given the augmented data). Hence, we are not going to deep dive into EDA and hypothesis testing. Instead, we will focus on building the ML product using different technologies.
#
# ## --------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Columns to remove

# %%
COLS_TO_REM = ['proposal_received_date','policy_issue_date', 'zipcode', 'county', 'state', 'agent_code', 'agent_dob', 'agent_doj']

# %% [markdown]
# - `proposal_received_date`: Derived `time_to_issue` from this column
# - `policy_issue_date`: Derived `time_to_issue` from this column
# - `zipcode`: Too many values, high cardinality
# - `county`: Too many values, high cardinality
# - `state`: Too many values, high cardinality
# - `agent_code`: Id column
# - `agent_dob`: Derived `agent_age` from this column
# - `agent_doj`: Derived `agent_tenure_days` from this column

# %%
def filter_df(df, COLS_TO_REM) -> pd.DataFrame:
    df = df.drop(COLS_TO_REM, axis = 1)
    return df

# %%
temp_df = filter_df(input_df, COLS_TO_REM)
temp_df.shape
# Out:
# (44948, 34)

# %%
input_df.shape
# Out:
# (44948, 42)

# %% [markdown]
# ## Feature Engineering Steps

# %% [markdown]
# #### Missing Value Imputation

# %% [markdown]
# We have only one column where missing value is present. `agent_persistency`. Impute missing value with median

# %%
agent_persistency_missing_perc = round(temp_df['agent_persistency'].isnull().mean()*100,2)

print(f'Total missing percentage of column agent_persistency is: {agent_persistency_missing_perc}% ')
# Out:
# Total missing percentage of column agent_persistency is: 0.26%

# %%
MISSING_COL = ['agent_persistency']

# %% [markdown]
# #### One-Hot Encoding

# %%
ONE_HOT_COLS = ['owner_gender', 'marital_status', 'smoker', 'medical', 'education', 'occupation', 'payment_freq',  
                'agent_status', 'agent_education']

# %% [markdown]
# #### Normalisation
#
# We will normalise the columns using `StandardScaler` because we have values at different scale

# %% [markdown]
# #### Creating train test split

# %%
temp_df.columns
# Out:
# Index(['owner_age', 'owner_gender', 'marital_status', 'num_nominee', 'smoker',
#        'medical', 'education', 'occupation', 'experience', 'income',
#        'negative_zipcode', 'family_member', 'existing_num_policy',
#        'has_critical_health_history', 'policy_term', 'payment_freq',
#        'annual_premium', 'sum_insured', 'agent_status', 'agent_education',
#        'agent_age', 'agent_tenure_days', 'agent_persistency',
#        'last_6_month_submissions', 'average_premium', 'is_reinstated',
#        'prev_persistency', 'num_complaints', 'target_completion_perc',
#        'has_contacted_in_last_6_months', 'credit_score', 'lapse',
#        'time_to_issue', 'prem_to_income_ratio'],
#       dtype='object')

# %%
FEATURES = ['owner_age', 'owner_gender', 'marital_status', 'num_nominee', 'smoker',
       'medical', 'education', 'occupation', 'experience', 'income',
       'negative_zipcode', 'family_member', 'existing_num_policy',
       'has_critical_health_history', 'policy_term', 'payment_freq',
       'annual_premium', 'sum_insured', 'agent_status', 'agent_education',
       'agent_age', 'agent_tenure_days', 'agent_persistency',
       'last_6_month_submissions', 'average_premium', 'is_reinstated',
       'prev_persistency', 'num_complaints', 'target_completion_perc',
       'has_contacted_in_last_6_months', 'credit_score',
       'time_to_issue', 'prem_to_income_ratio']

TARGET = 'lapse'

# %%
X_train, X_test, y_train, y_test = train_test_split(temp_df[FEATURES],
                                                    temp_df[TARGET],
                                                    test_size=0.3,
                                                    random_state = 786, 
                                                    shuffle = True,
                                                    stratify = temp_df[TARGET])

X_train.shape, X_test.shape
# Out:
# ((31463, 33), (13485, 33))

# %% [markdown]
# ### Creating data transformation pipeline

# %%
model_input_pipe = Pipeline([
    
    ('imputer_num', mdi.MeanMedianImputer(imputation_method = 'median', variables = MISSING_COL )), 
    
    ('onehot_encoder', ce.OneHotEncoder(top_categories=None,
                                        variables= ONE_HOT_COLS,
                                        drop_last=True)),
    
    ('normalisation', StandardScaler())
    
    # ('clf', LogisticRegression(penalty,random_state = 786))
])

# %%
X_train_trf = model_input_pipe.fit_transform(X_train)

# %%
X_train_trf
# Out:
# array([[-0.13723333, -0.34844439,  0.15699084, ...,  1.76218543,
#         -0.74815524, -0.58714994],
#        [-0.22828715, -0.34844439,  0.24685535, ...,  1.76218543,
#         -0.74815524, -0.58714994],
#        [-0.41039479, -0.34844439, -0.38219622, ..., -0.56747717,
#          1.33662099, -0.58714994],
#        ...,
#        [ 0.4090896 , -0.34844439,  0.87590693, ...,  1.76218543,
#         -0.74815524, -0.58714994],
#        [ 0.13592813, -0.34844439,  0.60631339, ..., -0.56747717,
#         -0.74815524, -0.58714994],
#        [-1.13882535, -0.34844439, -0.83151878, ..., -0.56747717,
#          1.33662099, -0.58714994]])

# %%
train = xgb.DMatrix(X_train_trf, label = y_train)
X_test_trf = model_input_pipe.transform(X_test)
valid = xgb.DMatrix(X_test_trf, label = y_test)

# %% [markdown]
# ### Running xgboost with hyperopt and tracking using mlflow

# %%
def objective(params):

    with mlflow.start_run():
        mlflow.set_tag("developer", "tanmoy")
        mlflow.set_tag("model", "xgboost hyperparam")

        mlflow.log_params(params)

        booster = xgb.train(params = params,
                            dtrain = train,
                            num_boost_round = 1000,
                            evals = [(valid, "validation")],
                            early_stopping_rounds = 50)

        
        y_pred = booster.predict(valid).round()
        
        accuracy = accuracy_score(y_test, y_pred)
        mlflow.log_metric("accuracy", accuracy)

        recall = recall_score(y_test, y_pred)
        mlflow.log_metric("recall", recall)

        precision = precision_score(y_test, y_pred)
        mlflow.log_metric("precision", precision)

        f1 = f1_score(y_test, y_pred)
        mlflow.log_metric("f1_score", f1)

        roc_auc = roc_auc_score(y_test, y_pred)
        mlflow.log_metric("roc_auc", roc_auc)

        return {"loss": -recall, 'status': STATUS_OK}

# %%
search_space =  {
    'max_depth' : scope.int(hp.quniform('max_depth', 4, 100, 1)),
    'learning_rate' : hp.loguniform('learning_rate', -3, 0),
    'min_child_weight' : hp.loguniform('min_child_weight', -1, 3),
    'objective' : 'binary:logistic',
    'seed' : 786
}

best_result = fmin(

    fn = objective,
    space = search_space,
    algo = tpe.suggest,
    max_evals = 20,
    trials = Trials()
)
# Out:
# [0]	validation-logloss:0.62074
# [1]	validation-logloss:0.55845
# [2]	validation-logloss:0.50428
# [3]	validation-logloss:0.45680
# [4]	validation-logloss:0.41488
# [5]	validation-logloss:0.37766
# [6]	validation-logloss:0.34445
# [7]	validation-logloss:0.31470
# [8]	validation-logloss:0.28794
# [9]	validation-logloss:0.26381
# [10]	validation-logloss:0.24199
# [11]	validation-logloss:0.22220
# [12]	validation-logloss:0.20423
# [13]	validation-logloss:0.18787
# [14]	validation-logloss:0.17295
# [15]	validation-logloss:0.15933
# [16]	validation-logloss:0.14688
# [17]	validation-logloss:0.13548
# [18]	validation-logloss:0.12503
# [19]	validation-logloss:0.11545
# [20]	validation-logloss:0.10665
# [21]	validation-logloss:0.09857
# [22]	validation-logloss:0.09113
# [23]	validation-logloss:0.08429
# [24]	validation-logloss:0.07799
# [25]	validation-logloss:0.07219
# [26]	validation-logloss:0.06685
# [27]	validation-logloss:0.06192
# [28]	validation-logloss:0.05737
# [29]	validation-logloss:0.05317
# [30]	validation-logloss:0.04930
# [31]	validation-logloss:0.04572
# [32]	validation-logloss:0.04241
# [33]	validation-logloss:0.03936
# [34]	validation-logloss:0.03654
# [35]	validation-logloss:0.03393
# [36]	validation-logloss:0.03152
# [37]	validation-logloss:0.02929
# [38]	validation-logloss:0.02722
# [39]	validation-logloss:0.02532
# [40]	validation-logloss:0.02355
# [41]	validation-logloss:0.02192
# [42]	validation-logloss:0.02041
# [43]	validation-logloss:0.01901
# [44]	validation-logloss:0.01771
# [45]	validation-logloss:0.01652
# [46]	validation-logloss:0.01541
# [47]	validation-logloss:0.01438
# [48]	validation-logloss:0.01343
# [49]	validation-logloss:0.01255
# [50]	validation-logloss:0.01174
# [51]	validation-logloss:0.01099
# [52]	validation-logloss:0.01030
# [53]	validation-logloss:0.00966
# [54]	validation-logloss:0.00907
# [55]	validation-logloss:0.00853
# [56]	validation-logloss:0.00803
# [57]	validation-logloss:0.00756
# [58]	validation-logloss:0.00713
# [59]	validation-logloss:0.00672
# [60]	validation-logloss:0.00636
# [61]	validation-logloss:0.00602
# [62]	validation-logloss:0.00571
# [63]	validation-logloss:0.00542
# [64]	validation-logloss:0.00515
# [65]	validation-logloss:0.00490
# [66]	validation-logloss:0.00467
# [67]	validation-logloss:0.00446
# [68]	validation-logloss:0.00426
# [69]	validation-logloss:0.00408
# [70]	validation-logloss:0.00391
# [71]	validation-logloss:0.00376
# [72]	validation-logloss:0.00361
# [73]	validation-logloss:0.00348
# [74]	validation-logloss:0.00336
# [75]	validation-logloss:0.00329
# [76]	validation-logloss:0.00323
# [77]	validation-logloss:0.00316
# [78]	validation-logloss:0.00306
# [79]	validation-logloss:0.00301
# [1]	validation-logloss:0.05937
# [2]	validation-logloss:0.02420
# [3]	validation-logloss:0.01034
# [4]	validation-logloss:0.00482
# [5]	validation-logloss:0.00261
# [6]	validation-logloss:0.00173
# [7]	validation-logloss:0.00121
# [8]	validation-logloss:0.00094
# [9]	validation-logloss:0.00078
# [10]	validation-logloss:0.00073
# [11]	validation-logloss:0.00068
# [12]	validation-logloss:0.00066
# [13]	validation-logloss:0.00061
# [14]	validation-logloss:0.00060
# [15]	validation-logloss:0.00061
# [16]	validation-logloss:0.00061
# [17]	validation-logloss:0.00059
# [18]	validation-logloss:0.00060
# [19]	validation-logloss:0.00061
# [20]	validation-logloss:0.00062
# [21]	validation-logloss:0.00062
# [22]	validation-logloss:0.00062
# [23]	validation-logloss:0.00062
# [24]	validation-logloss:0.00062
# [25]	validation-logloss:0.00062
# [26]	validation-logloss:0.00061
# [27]	validation-logloss:0.00061
# [28]	validation-logloss:0.00061
# [29]	validation-logloss:0.00061
# [30]	validation-logloss:0.00062
# [31]	validation-logloss:0.00061
# [32]	validation-logloss:0.00062
# [33]	validation-logloss:0.00061
# [34]	validation-logloss:0.00061
# [35]	validation-logloss:0.00061
# [36]	validation-logloss:0.00060
# [37]	validation-logloss:0.00061
# [38]	validation-logloss:0.00061
# [39]	validation-logloss:0.00062
# [40]	validation-logloss:0.00062
# [41]	validation-logloss:0.00062
# [42]	validation-logloss:0.00062
# [43]	validation-logloss:0.00061
# [44]	validation-logloss:0.00062
# [45]	validation-logloss:0.00062
# [46]	validation-logloss:0.00062
# [47]	validation-logloss:0.00061
# [48]	validation-logloss:0.00061
# [49]	validation-logloss:0.00062
# [50]	validation-logloss:0.00061
# [51]	validation-logloss:0.00062
# [52]	validation-logloss:0.00062
# [53]	validation-logloss:0.00062
# [54]	validation-logloss:0.00062
# [55]	validation-logloss:0.00063
# [56]	validation-logloss:0.00063
# [57]	validation-logloss:0.00062
# [58]	validation-logloss:0.00062
# [59]	validation-logloss:0.00062
# [60]	validation-logloss:0.00062
# [61]	validation-logloss:0.00062
# [62]	validation-logloss:0.00062
# [63]	validation-logloss:0.00061
# [64]	validation-logloss:0.00061
# [65]	validation-logloss:0.00061
# [66]	validation-logloss:0.00061
# 100%|██████████| 20/20 [06:36<00:00, 19.81s/trial, best loss: -0.9998220007119971]

# %% [markdown]
# ### Finalising model
# - Running with best model params (best model chosen in terms of least execution time)
# - Autologging along with customised metrics logging
# - storing prerocessor `model_input_pipe` as an artifact
# - storing model as an artifact

# %%
best_params = {
    'learning_rate'	: 0.2814570170492009,
    'max_depth' :	7,
    'min_child_weight' :	0.7932377259600513,
    'objective' :	'binary:logistic',
    'seed' :	786
}

with mlflow.start_run():
    mlflow.xgboost.autolog()
    mlflow.set_tag("developer", "tanmoy")
    mlflow.set_tag("model", "xgboost")
    mlflow.set_tag("type", "final")

    xgbooster = xgb.train(
                        params = best_params,
                        dtrain = train,
                        num_boost_round = 1000,
                        evals = [(valid, "validation")],
                        early_stopping_rounds = 50)

    y_pred = xgbooster.predict(valid).round()
            
    accuracy = accuracy_score(y_test, y_pred)
    mlflow.log_metric("accuracy", accuracy)

    recall = recall_score(y_test, y_pred)
    mlflow.log_metric("recall", recall)

    precision = precision_score(y_test, y_pred)
    mlflow.log_metric("precision", precision)

    f1 = f1_score(y_test, y_pred)
    mlflow.log_metric("f1_score", f1)

    roc_auc = roc_auc_score(y_test, y_pred)
    mlflow.log_metric("roc_auc_score", roc_auc)

    with open("models/preprocessor.b", "wb") as f_out:
        pickle.dump(model_input_pipe, f_out)

    mlflow.log_artifact("models/preprocessor.b", artifact_path = "preprocessor")
    mlflow.xgboost.log_model(xgbooster, artifact_path= "model_mlflow")

mlflow.end_run()
# Out:
# 2023/01/10 17:09:39 WARNING mlflow.utils.autologging_utils: You are using an unsupported version of xgboost. If you encounter errors during autologging, try upgrading / downgrading xgboost to a supported version, or try upgrading MLflow.
# [0]	validation-logloss:0.45113
# [1]	validation-logloss:0.31252
# [2]	validation-logloss:0.22318
# [3]	validation-logloss:0.16228
# [4]	validation-logloss:0.11937
# [5]	validation-logloss:0.08854
# [6]	validation-logloss:0.06607
# [7]	validation-logloss:0.04955
# [8]	validation-logloss:0.03732
# [9]	validation-logloss:0.02823
# [10]	validation-logloss:0.02144
# [11]	validation-logloss:0.01637
# [12]	validation-logloss:0.01257
# [13]	validation-logloss:0.00971
# [14]	validation-logloss:0.00758
# [15]	validation-logloss:0.00597
# [16]	validation-logloss:0.00477
# [17]	validation-logloss:0.00382
# [18]	validation-logloss:0.00315
# [19]	validation-logloss:0.00262
# [20]	validation-logloss:0.00219
# [21]	validation-logloss:0.00186
# [22]	validation-logloss:0.00162
# [23]	validation-logloss:0.00143
# [24]	validation-logloss:0.00126
# [25]	validation-logloss:0.00114
# [26]	validation-logloss:0.00104
# [27]	validation-logloss:0.00096
# [28]	validation-logloss:0.00091
# [29]	validation-logloss:0.00087
# [30]	validation-logloss:0.00082
# [31]	validation-logloss:0.00080
# [32]	validation-logloss:0.00078
# [33]	validation-logloss:0.00076
# [34]	validation-logloss:0.00074
# [35]	validation-logloss:0.00074
# [36]	validation-logloss:0.00073
# [37]	validation-logloss:0.00071
# [38]	validation-logloss:0.00069
# [39]	validation-logloss:0.00069
# [40]	validation-logloss:0.00069
# [41]	validation-logloss:0.00068
# [42]	validation-logloss:0.00069
# [43]	validation-logloss:0.00068
# [44]	validation-logloss:0.00067
# [45]	validation-logloss:0.00067
# [46]	validation-logloss:0.00066
# [47]	validation-logloss:0.00065
# [48]	validation-logloss:0.00065
# [49]	validation-logloss:0.00066
# [50]	validation-logloss:0.00066
# [51]	validation-logloss:0.00065
# [52]	validation-logloss:0.00066
# [53]	validation-logloss:0.00065
# [54]	validation-logloss:0.00065
# [55]	validation-logloss:0.00066
# [56]	validation-logloss:0.00066
# [57]	validation-logloss:0.00066
# [58]	validation-logloss:0.00066
# [59]	validation-logloss:0.00066
# [60]	validation-logloss:0.00066
# [61]	validation-logloss:0.00065
# [62]	validation-logloss:0.00065
# [63]	validation-logloss:0.00065
# [64]	validation-logloss:0.00065
# [65]	validation-logloss:0.00065
# [66]	validation-logloss:0.00065
# [67]	validation-logloss:0.00065
# [68]	validation-logloss:0.00065
# [69]	validation-logloss:0.00066
# [70]	validation-logloss:0.00065
# [71]	validation-logloss:0.00065
# [72]	validation-logloss:0.00066
# [73]	validation-logloss:0.00065
# [74]	validation-logloss:0.00066
# [75]	validation-logloss:0.00066
# [76]	validation-logloss:0.00066
# [77]	validation-logloss:0.00066
# [78]	validation-logloss:0.00066
# [79]	validation-logloss:0.00066
# [80]	validation-logloss:0.00065
# [81]	validation-logloss:0.00066
# [82]	validation-logloss:0.00065
# [83]	validation-logloss:0.00066
# [84]	validation-logloss:0.00066
# [85]	validation-logloss:0.00066
# [86]	validation-logloss:0.00066
# [87]	validation-logloss:0.00066
# [88]	validation-logloss:0.00066
# [89]	validation-logloss:0.00066
# [90]	validation-logloss:0.00066
# [91]	validation-logloss:0.00066
# [92]	validation-logloss:0.00066
# [93]	validation-logloss:0.00066
# [94]	validation-logloss:0.00065
# [95]	validation-logloss:0.00065
# [96]	validation-logloss:0.00065
# [97]	validation-logloss:0.00065
# [98]	validation-logloss:0.00066
# [99]	validation-logloss:0.00066
# [100]	validation-logloss:0.00066
# [101]	validation-logloss:0.00066
# [102]	validation-logloss:0.00066
# [103]	validation-logloss:0.00066
# [104]	validation-logloss:0.00065
# [105]	validation-logloss:0.00065
# [106]	validation-logloss:0.00065
# [107]	validation-logloss:0.00065
# [108]	validation-logloss:0.00065
# [109]	validation-logloss:0.00065
# [110]	validation-logloss:0.00065
# [111]	validation-logloss:0.00065
# 2023/01/10 17:09:43 WARNING mlflow.xgboost: Failed to infer model signature: could not sample data to infer model signature: please ensure that autologging is enabled before constructing the dataset.

# %% [markdown]
# #### Run Name: `caring-rat-457`
# #### Run Id: `01e625740ecc4808ba73bc371ef82dcc`

# %% [markdown]
# #### Load model locally and make predictions

# %%
# Set the uri
logged_model = r'mlruns/1/01e625740ecc4808ba73bc371ef82dcc/artifacts/model_mlflow/'

# Load model as a PyFuncModel
loaded_model = mlflow.pyfunc.load_model(logged_model)
print(loaded_model)

# load as a xgboost model
xgboost_model = mlflow.xgboost.load_model(logged_model)
print(xgboost_model)

# Predict on a Pandas DataFrame.
predictions = xgboost_model.predict(valid)
print(predictions[:10])
# Out:
# mlflow.pyfunc.loaded_model:
#   artifact_path: model_mlflow
#   flavor: mlflow.xgboost
#   run_id: 01e625740ecc4808ba73bc371ef82dcc
#
# <xgboost.core.Booster object at 0x0000017C19A68130>
# [4.6671816e-05 1.3253766e-05 4.8075861e-05 1.0657247e-05 3.2219115e-05
#  9.9997973e-01 1.8963719e-05 9.9972111e-01 9.9997938e-01 1.7128143e-05]

# %% [markdown]
# #### Checking the distribution of `1` and `0` in the predicted vs actual data

# %%
comp_df = pd.DataFrame({'y_test': y_test, 'predicted_proba': predictions})
comp_df
# Out:
#                y_test  predicted_proba
# policy_number
# 40358               0         0.000047
# 3913                0         0.000013
# 38344               0         0.000048
# 4276                0         0.000011
# 17548               0         0.000032
# ...               ...              ...
# 2816                0         0.000057
# 16945               1         0.999496
# 6403                0         0.000051
# 9447                0         0.000017
# 5236                0         0.000014
#
# [13485 rows x 2 columns]

# %%
sns.displot(data= comp_df, x = "predicted_proba", hue="y_test", kind="kde")
